# %%
kiran, X = 20, 10; print(KiranX := kiran + X)
# Out:
# 30

# %%
x= "w"
print(f"team kiran is on duty, members => {x}")
# Out:
# team kiran is on duty, members => Vijay Gangwar Pandey

# %% [markdown]
# # hello I'm here for UI
